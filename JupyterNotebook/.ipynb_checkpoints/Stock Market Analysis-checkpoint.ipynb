# %%
#Let's go ahead and start with some imports
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader import data, wb, DataReader
#from pandas-datareader import  wb, data, DataReader

# For time stamps
from datetime import datetime

# For division
from __future__ import division

# %%
# Tesla and Exxon Mobile tickers for analysis
tech_list = ['TSLA','MSFT','ADE','AMZN']

# Set up End and Start times for data grab
end = datetime.now()
start = datetime(end.year - 1,end.month,end.day)


#For loop for grabing yahoo finance data and setting as a dataframe

for stock in tech_list:   
    # Set DataFrame as the Stock Ticker
    globals()[stock] = DataReader(stock,'yahoo',start,end)

# %%
TSLA.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-11-17  183.490005  189.490005  182.110001  188.660004  188.660004
# 2016-11-18  190.649994  193.000000  185.000000  185.020004  185.020004
# 2016-11-21  185.039993  188.889999  184.410004  184.520004  184.520004
# 2016-11-22  185.839996  191.470001  183.710007  191.169998  191.169998
# 2016-11-23  190.610001  195.639999  189.000000  193.139999  193.139999
#
#              Volume
# Date
# 2016-11-17  4887100
# 2016-11-18  5210300
# 2016-11-21  4361000
# 2016-11-22  5603400
# 2016-11-23  4885300

# %%
ADE.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2016-11-17  35.500000  35.500000  35.000000  35.450001  35.450001   40795
# 2016-11-18  35.000000  35.529999  34.500000  34.509998  34.509998   35863
# 2016-11-21  34.500000  34.549999  34.500000  34.799999  34.799999    8878
# 2016-11-22  34.549999  34.549999  34.549999  34.180000  34.180000      70
# 2016-11-23  34.180000  34.549999  33.250000  33.599998  33.599998    1339

# %%
AMZN.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-11-17  749.320007  757.500000  748.000000  756.400024  756.400024
# 2016-11-18  761.000000  767.739990  757.640015  760.159973  760.159973
# 2016-11-21  766.000000  780.349976  765.109985  780.000000  780.000000
# 2016-11-22  788.169983  792.400024  781.000000  785.330017  785.330017
# 2016-11-23  781.729980  781.750000  773.119995  780.119995  780.119995
#
#              Volume
# Date
# 2016-11-17  3690100
# 2016-11-18  4373400
# 2016-11-21  4614600
# 2016-11-22  5311300
# 2016-11-23  3522500

# %%
TSLA["Adj Close"].plot(legend=True, figsize=(10,4))

# %%
TSLA["Volume"].plot(legend=True, figsize=(10,4), color="green")

# %%
# plot volume and Adj Close price 
fig, ax = plt.subplots()
ax.plot(TSLA['Volume'], color = 'green')
ax2 =ax.twinx()
ax2.plot(TSLA['Adj Close'], color ='blue')
sns.despine(ax=ax, right=True, left=True)
sns.despine(ax=ax2, left=True, right=False)
ax2.spines['right'].set_color('white')

#observation -- there seems to be a correlation between volumne traded vs price fluctuation magnitude

# %%
# get closing price of stocks in a new DF
closing_df = DataReader(['TSLA', 'MSFT','ADE','AMZN'],'yahoo',start,end)['Adj Close']
closing_df.head()
# Out:
#                   ADE        AMZN       MSFT        TSLA
# Date
# 2016-11-17  35.450001  756.400024  59.315563  188.660004
# 2016-11-18  34.509998  760.159973  59.031898  185.020004
# 2016-11-21  34.799999  780.000000  59.530758  184.520004
# 2016-11-22  34.180000  785.330017  59.785076  191.169998
# 2016-11-23  33.599998  780.119995  59.080803  193.139999

# %%
#calculate the percentage change of all stock
stock_rets= closing_df.pct_change()
stock_rets.head()
# Out:
#                  ADE      AMZN      MSFT      TSLA
# Date
# 2016-11-17       NaN       NaN       NaN       NaN
# 2016-11-18 -0.026516  0.004971 -0.004782 -0.019294
# 2016-11-21  0.008403  0.026100  0.008451 -0.002702
# 2016-11-22 -0.017816  0.006833  0.004272  0.036039
# 2016-11-23 -0.016969 -0.006634 -0.011780  0.010305

# %%
# Let's go ahead and plot out several moving averages
ma_day = [10,20,50] # moving average for 10, 20, 50 days

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    TSLA[column_name]=Series.rolling(TSLA['Adj Close'],ma).mean()

# %%
TSLA.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-11-17  183.490005  189.490005  182.110001  188.660004  188.660004
# 2016-11-18  190.649994  193.000000  185.000000  185.020004  185.020004
# 2016-11-21  185.039993  188.889999  184.410004  184.520004  184.520004
# 2016-11-22  185.839996  191.470001  183.710007  191.169998  191.169998
# 2016-11-23  190.610001  195.639999  189.000000  193.139999  193.139999
#
#              Volume  MA for 10 days  MA for 20 days  MA for 50 days
# Date
# 2016-11-17  4887100             NaN             NaN             NaN
# 2016-11-18  5210300             NaN             NaN             NaN
# 2016-11-21  4361000             NaN             NaN             NaN
# 2016-11-22  5603400             NaN             NaN             NaN
# 2016-11-23  4885300             NaN             NaN             NaN

# %%
#plot moving avarages
TSLA[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4))

# %%
# We'll use pct_change to find the percent change for each day
TSLA['Daily Return'] = TSLA['Adj Close'].pct_change()
# Then we'll plot the daily return percentage
TSLA['Daily Return'].plot(figsize=(12,4),legend=True,linestyle='--',marker='o')

# %%
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn
sns.distplot(TSLA['Daily Return'].dropna(),bins=100,color='purple')

# Could have also done:
#AAPL['Daily Return'].hist()

# %%
sns.jointplot('TSLA','MSFT',stock_rets,kind='scatter')

# %%
#Risk analysis 

# Let's start by defining a new DataFrame as a clenaed version of the oriignal stock_rets DataFrame
rets = stock_rets.dropna()

area = np.pi*40 #area of the circle to make is bigger in the plot

plt.scatter(rets.mean(), rets.std(),alpha = 0.5,s =area)

# Set the x and y limits of the plot (optional, remove this if you don't see anything in your plot)
plt.ylim([-0.01,0.030])
plt.xlim([-0.003,0.004])

#Set the plot axis titles
plt.xlabel('Expected returns')
plt.ylabel('Risk')

# Label the scatter plots, for more info on how this is done, chekc out the link below
# http://matplotlib.org/users/annotations_guide.html
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'left', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.6'))

# %%
#Value at rish using bootstrap method
#Calculate Value at risk  for Tesla

# The 0.05 empirical quantile of daily returns
rets['TSLA'].quantile(0.01)

#the 0.05 empirical quantile of daily return is -0.036. This means with 95% confidence our maximum daily lost will
#not exceed 3.6%
# Out:
# -0.05994090835327337

# %%
#Calculate Value at risk  for Amazon

# The 0.05 empirical quantile of daily returns
rets['AMZN'].quantile(0.01)

#the 0.05 empirical quantile of daily return is -0.015. THis means with a 95% confidence the maximum daily lost will 
#not exceeed 1.5 %
# Out:
# -0.028587913321372505

# %%
#Calculate Value at risk  for Bitcoin Group

# The 0.05 empirical quantile of daily returns
rets['ADE'].quantile(0.05)

#the 0.01 empirical quantile of daily return is -0.015. THis means with a 95% confidence the maximum daily lost will 
#not exceeed 3.1%
# Out:
# -0.03191850594227502

# %%
#Value at risk using Monte Carlo Method
 
    # Set up our time horizon
days = 365

# Now our delta
dt = 1/days

# Now let's grab our mu (drift) from the expected return data we got for AAPL
mu = rets.mean()['TSLA']

# Now let's grab the volatility of the stock from the std() of the average return
sigma = rets.std()['TSLA']

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
    ''' This function takes in starting stock price, days of simulation,mu,sigma, and returns simulated price array'''
    
    # Define a price array
    price = np.zeros(days)
    price[0] = start_price
    # Schok and Drift
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    # Run price array for number of days
    for x in range(1,days):
        
        # Calculate Schock
        shock[x] = np.random.normal(loc=mu * dt, scale=sigma * np.sqrt(dt))
        # Calculate Drift
        drift[x] = mu * dt
        # Calculate Price
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price

# %%
TSLA.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-11-17  183.490005  189.490005  182.110001  188.660004  188.660004
# 2016-11-18  190.649994  193.000000  185.000000  185.020004  185.020004
# 2016-11-21  185.039993  188.889999  184.410004  184.520004  184.520004
# 2016-11-22  185.839996  191.470001  183.710007  191.169998  191.169998
# 2016-11-23  190.610001  195.639999  189.000000  193.139999  193.139999
#
#              Volume
# Date
# 2016-11-17  4887100
# 2016-11-18  5210300
# 2016-11-21  4361000
# 2016-11-22  5603400
# 2016-11-23  4885300

# %%
# Get start price from GOOG.head()
start_price = 183.49

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for TSLA')

# %%
# Set a large numebr of runs
runs = 100000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

# Set the print options of numpy to only display 0-5 points from an array to suppress output
np.set_printoptions(threshold=5)

for run in range(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 1)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for TSLA Stock after %s days" % days, weight='bold');
